# %% [markdown]
# # Foundations of Data Science
# ## Homework 2

# %% [markdown]
# Student Name: Vaishali Pari
#
# Student Netid: vp1096
# ***

# %% [markdown]
# ### Part 1: Case study
# - Read [this article](http://www.nytimes.com/2012/02/19/magazine/shopping-habits.html) in the New York Times.
# - Use what we've learned in class and from the book to describe how one could set Target's problem up as a predictive modeling problem, such that they could have gotten the results that they did.  Formulate your solution as a proposed plan using our data science terminology.  Include aspects of the Data Science Workflow that you see as relevant to solving the problem.  Be precise but concise.

# %% [markdown]
# Predective Modeling Approach for Target's problem to increased sales by focusing on the buying habits of pregnent customes.
# Choosing the Target Variable: predict when their female customers will enter the trimester of pregnency
# From the article, target wants to find the customers who are pregnent and send then coupons and have scientific evidence of how major life events are a turning point in changing peoples habbits. To be ahead of other retailers target decides to send baby item coupons to pregnent customers even before the baby is born.
# Feature Selection: purchase or lack of purchase of specific products
# we collect some training data set and narrow down to target's regular customers. By analysing the patterns of customers buying vitamine supliments,pregnency tests,lotion, etc we can predict the pregnant customers. we can assign a purchase basket score to keep track of them.
# Algorithm Selection: To find the pregnent customers and what products to suggest them can be learned from applying some algorith on the dataset. We can choose logistic regression, which combines the prediction and feature selection steps.
# Finally send out email coupons to the selected customers and keep track of who uses it and send further rewards. Also send out coupons designed in a casual way that they don't realise its sent after spying on them.
# This predictive modelling of target turned out to be a success not only because of analysing the customer patterns and targeting them but because they focused the target based on the scientific study of the human habbit of the cue-routine-reward system.

# %% [markdown]
# ### Part 2: Exploring data in the command line
# For this part we will be using the data file located in `"data/advertising_events.csv"`. This file consists of records that pertain to some online advertising events on a given day. There are 4 comma separated columns in this order: `userid`, `timestamp`, `domain`, and `action`. These fields are of type `int` (continuous), `int` (continuous), `string`, and `int` (category) respectively. Answer the following questions using Linux/Unix bash commands. All questions can be answered in one line (sometimes, with pipes)! Some questions will have many possible solutions. Don't forget that in IPython notebooks you must prefix all bash commands with an exclamation point, i.e. `"!command arguments"`.
#
# [Hints: You can experiment with whatever you want in the notebook and then delete things to construct your answer later.  You can also use ssh to use the actual bash shell on EC2 and then just paste your answers here. Recall that once you enter the "!" then filename completion should work.]

# %% [markdown]
# 1. How many records (lines) are in this file?

# %%
# !wc -l advertising_events.csv
# Out:
#    10341 advertising_events.csv

# %% [markdown]
# 2\. How many unique users are in this file? (hint: consider the 'cut' command and use pipe operator '|')

# %%
# !cut -d, -f 1 advertising_events.csv | uniq | wc -l
# Out:
#    10331

# %% [markdown]
# 3\. Rank all domains by the number of visits they received in descending order. (hint: consider the 'cut', 'uniq' and 'sort' commands and the pipe operator).

# %%
# !cut -d, -f 3 advertising_events.csv |sort |uniq -c |sort -n -r
# Out:
# 3114 google.com
# 2092 facebook.com
# 1036 youtube.com
# 1034 yahoo.com
# 1022 baidu.com
#  513 wikipedia.org
#  511 amazon.com
#  382 qq.com
#  321 twitter.com
#  316 taobao.com

# %% [markdown]
# 4\. List all records for the user with user id 37. (hint: this can be done using 'grep')

# %%
# !grep -w '37' advertising_events.csv
# Out:
# 37,648061658,google.com,0
# 37,642479972,google.com,2
# 37,644493341,facebook.com,2
# 37,654941318,facebook.com,1
# 37,649979874,baidu.com,1
# 37,653061949,yahoo.com,1
# 37,655020469,google.com,3
# 37,640878012,amazon.com,0
# 37,659864136,youtube.com,1
# 37,640361378,yahoo.com,1
# 37,653862134,facebook.com,0
# 37,648828970,youtube.com,0

# %% [markdown]
# ### Part 3: Dealing with data Pythonically

# %%
# You might find these packages useful. You may import any others you want!
import pandas as pd
import numpy as np

# %% [markdown]
# 1\. Load the data set `"data/ads_dataset.tsv"` into a Python Pandas data frame called `ads`.

# %%
adsData = pd.read_csv('ads_dataset.tsv', sep='\t')
adsData
# Out:
#      isbuyer  buy_freq  visit_freq  buy_interval  sv_interval  \
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           2           0.0     0.500000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           2           0.0    29.791670
# NaN        0       NaN           3           0.0    45.479170
# NaN        0       NaN           1           0.0     0.000000
# NaN        1       1.0           2           0.0     0.958333
# NaN        0       NaN           2           0.0    21.333330
# NaN        0       NaN           1           0.0     0.000000
# NaN        0       NaN           1           0.0     0.000000
# ...

# %% [markdown]
# 2\. Write a Python function called `getDfSummary()` that does the following:
# - Takes as input a data frame
# - For each variable in the data frame calculates the following features:
#   - `number_nan` to count the number of missing not-a-number values
#   - Ignoring missing, NA, and Null values:
#     - `number_distinct` to count the number of distinct values a variable can take on
#     - `mean`, `max`, `min`, `std` (standard deviation), and `25%`, `50%`, `75%` to correspond to the appropriate percentiles
# - All of these new features should be loaded in a new data frame. Each row of the data frame should be a variable from the input data frame, and the columns should be the new summary features.
# - Returns this new data frame containing all of the summary information
#
# Hint: The pandas `describe()` [(manual page)](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html) method returns a useful series of values that can be used here.

# %%
def getDfSummary(input_data):
    df = pd.DataFrame(input_data)
    newdf=pd.DataFrame(index=df.columns)
    newdf['number_nan']=df.isnull().sum()
    d=pd.DataFrame(df.describe())
    d=d.T
    frames=[newdf,d]
    output_data=pd.concat(frames,axis=1, join='inner')
    output_data= output_data.rename(columns={'count': 'number_distinct'})
    return output_data
result=getDfSummary(adsData)
result
# Out:
#                      number_nan  number_distinct        mean          std  \
# isbuyer                       0          54584.0    0.042632     0.202027
# buy_freq                  52257           2327.0    1.240653     0.782228
# visit_freq                    0          54584.0    1.852777     2.921820
# buy_interval                  0          54584.0    0.210008     3.922016
# sv_interval                   0          54584.0    5.825610    17.595442
# expected_time_buy             0          54584.0   -0.198040     4.997792
# expected_time_visit           0          54584.0  -10.210786    31.879722
# last_buy                      0          54584.0   64.729335    53.476658
# last_visit                    0          54584.0   64.729335    53.476658
# multiple_buy                  0          54584.0    0.006357     0.079479
# multiple_visit                0          54584.0    0.277444     0.447742
# uniq_urls                     0          54584.0   86.569343    61.969765
# ...

# %% [markdown]
# 3\. How long does it take for your `getDfSummary()` function to work on your `ads` data frame? Show us the results below.
#
# Hint: `%timeit getDfSummary(ads)`

# %%
timeit getDfSummary(adsData)
# Out:
# 10 loops, best of 3: 61.3 ms per loop

# %% [markdown]
# 4\. Using the results returned from `getDfSummary()`, which fields, if any, contain missing `NaN` values?

# %%
print 'Fields containing NAN values are:'
NanFields=result.index[result['number_nan'] != 0].tolist()
NanFields
# Out:
# Fields containing NAN values are:
# ['buy_freq']

# %% [markdown]
# 5\. For the fields with missing values, does it look like the data is missing at random? Are there any other fields that correlate perfectly, or predict that the data is missing? What would be an appropriate method for filling in missing values?
#
# Hint: create another data frame that has just the records with a missing value. Get a summary of this data frame using `getDfSummary()` and compare the differences. Do some feature distributions change dramatically?

# %%
#We have missing data in buy_freq and the data is missing for most of the records. 
#Finding correlation between fields
adsData.corr(method='pearson', min_periods=1)
#From the result it can be predicted that multiple_buy and buy_freq are correlated(0.735). 
#If a buyer has bought multiple times then his buy frequency might take its value
# Out:
#                       isbuyer  buy_freq  visit_freq  buy_interval  \
# isbuyer              1.000000       NaN    0.326373      0.253749
# buy_freq                  NaN  1.000000    0.487548      0.398839
# visit_freq           0.326373  0.487548    1.000000      0.262660
# buy_interval         0.253749  0.398839    0.262660      1.000000
# sv_interval          0.037496  0.000280    0.140983      0.042134
# expected_time_buy   -0.187782 -0.291767   -0.147219      0.005762
# expected_time_visit -0.080492  0.060817   -0.121919      0.010266
# last_buy            -0.089678 -0.126793   -0.171388     -0.046015
# last_visit          -0.089678 -0.126793   -0.171388     -0.046015
# multiple_buy         0.379045  0.735054    0.354157      0.669442
# multiple_visit       0.231174  0.154837    0.472163      0.083427
# uniq_urls           -0.006641  0.042624    0.039079      0.013895
# num_checkins        -0.004424  0.042764    0.048881      0.008804
# ...

# %%
#data frame that has just the records with a missing value and summary of this data frame using getDfSummary()
null_data = adsData[adsData.isnull().any(axis=1)]
getDfSummary(null_data)
# Out:
#                      number_nan  number_distinct        mean          std  \
# isbuyer                       0          52257.0    0.000000     0.000000
# buy_freq                  52257              0.0         NaN          NaN
# visit_freq                    0          52257.0    1.651549     2.147955
# buy_interval                  0          52257.0    0.000000     0.000000
# sv_interval                   0          52257.0    5.686388    17.623555
# expected_time_buy             0          52257.0    0.000000     0.000000
# expected_time_visit           0          52257.0   -9.669298    31.239030
# last_buy                      0          52257.0   65.741317    53.484622
# last_visit                    0          52257.0   65.741317    53.484622
# multiple_buy                  0          52257.0    0.000000     0.000000
# multiple_visit                0          52257.0    0.255602     0.436203
# uniq_urls                     0          52257.0   86.656180    61.996711
# ...

# %%
#filling Nan values with mean
adsData.fillna(adsData.mean())
# Out:
#      isbuyer  buy_freq  visit_freq  buy_interval  sv_interval  \
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           2           0.0     0.500000
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           2           0.0    29.791670
# NaN        0  1.240653           3           0.0    45.479170
# NaN        0  1.240653           1           0.0     0.000000
# NaN        1  1.000000           2           0.0     0.958333
# NaN        0  1.240653           2           0.0    21.333330
# NaN        0  1.240653           1           0.0     0.000000
# NaN        0  1.240653           1           0.0     0.000000
# ...

# %% [markdown]
# 6\. Which variables are binary?

# %%
bool_cols = [col for col in adsData
             if adsData[[col]].dropna().isin([0, 1]).all().values]

bool_cols
# Out:
# ['isbuyer', 'multiple_buy', 'multiple_visit', 'y_buy']
